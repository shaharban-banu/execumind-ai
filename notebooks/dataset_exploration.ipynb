# %%
import os
import sys
sys.path.append(os.path.abspath(".."))

# %%
from config.dataset_config import DATASETS
from etl.extract import extract_csv
from etl.validate import *

# %%
for table_name,metadata in DATASETS.items():
    print(table_name.upper())
    print("="*10)

    filename=metadata["file"]
    df=extract_csv(f"../data/raw/{filename}")
    print("shape :",dataset_shape(df))
    print("Missing values :")
    print(check_missing_values(df))
    print("Duplicates :",check_duplicates(df))
    print("Primary key issues :",validate_primary_key(df,metadata["primary_key"]))
    
    print("="*20)
# Out:
# CUSTOMERS
# ...
# shape : (99441, 5)
# Missing values :
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
# Duplicates : 0
# Primary key issues : 0
# ...
# ORDERS
# ...
# shape : (99441, 8)
# Missing values :
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
# Duplicates : 0
# Primary key issues : 0
# ...
# ORDER_ITEMS
# ...
# shape : (112650, 7)
# Missing values :
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
# Duplicates : 0
# ...
